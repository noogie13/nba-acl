# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
season_stats = pd.read_csv('data/Seasons_Stats.csv')

# %%
season_stats.loc[season_stats['Player'] == 'Billy Cunningham*']
# Out:
#       Unnamed: 0    Year             Player Pos   Age   Tm     G  GS      MP  \
# 2243        2243  1966.0  Billy Cunningham*  SF  22.0  PHI  80.0 NaN  2134.0
# 2378        2378  1967.0  Billy Cunningham*  SF  23.0  PHI  81.0 NaN  2168.0
# 2518        2518  1968.0  Billy Cunningham*  SF  24.0  PHI  74.0 NaN  2076.0
# 2697        2697  1969.0  Billy Cunningham*  PF  25.0  PHI  82.0 NaN  3345.0
# 2902        2902  1970.0  Billy Cunningham*  SF  26.0  PHI  81.0 NaN  3194.0
# 3117        3117  1971.0  Billy Cunningham*  SF  27.0  PHI  81.0 NaN  3090.0
# 3359        3359  1972.0  Billy Cunningham*  SF  28.0  PHI  75.0 NaN  2900.0
# 4163        4163  1975.0  Billy Cunningham*  SF  31.0  PHI  80.0 NaN  2859.0
# 4431        4431  1976.0  Billy Cunningham*  SF  32.0  PHI  20.0 NaN   640.0
#
#        PER  ...    FT%    ORB    DRB     TRB    AST   STL   BLK  TOV     PF  \
# 2243  15.7  ...  0.634    NaN    NaN   599.0  207.0   NaN   NaN  NaN  301.0
# ...

# %%
def search(string):
    return season_stats[season_stats['Player'].str.contains(string)==True]

# %%
players_dates = {'Billy Cunningham*':1975,'Doug Collins':1980, 'Toby Knight':1980, 'Mitch Kupchak':1981, 'Campy Russell':1982, 'Michael Brooks':1984, 'Walter Davis':1984, 'Bernard King*':1985, 'Derek Smith':1985, 'Jamaal Wilkes*':1985, 'Eddie Lee':1985, 'Dave Corzine':1989, 'Larry Krystkowiak':1989, 'Johnny Dawkins':1990, 'Ron Harper':1990, 'Mark Price':1990, 'Roy Tarpley':1990, 'Terry Cummings':1992, 'Jack Haley':1992, 'Tim Hardaway':1993, 'Sarunas Marciulionis*':1993, 'Doc Rivers':1993, 'Brent Price':[1994,1997], 'Danny Manning':[1995,1998], 'Keith Jennings':1996, 'Tim Legler':1996, 'Haywoode Workman':1996, 'Emanual Davis':1996, 'Popeye Jones':1997, 'Eric Williams':1997, 'Baron Davis':[1998,2012], 'Jerome James':1999, 'Raef LaFrentz':1999, 'Speedy Claxton':2000, 'Tom Gugliotta':2000, 'Jamal Crawford':2001, 'Bonzi Wells':2001, 'Raul Lopez':[2001,2002], 'Al Harrington':2002, 'Steven Hunter':2002, 'Vitaly Potapenko':2002, 'Obinna Ekezie':2003, 'Marcus Fizer':2003, 'Pat Garrity':2003, 'Ben Handlogten':2003, 'Jay Williams':2003, 'Alex Garcia':2004, 'Willie Green':2005, 'Nene':2005, 'Nenad Krstic':2006, 'Robert Swift':2006, 'Tony Allen':2007, 'Shaun Livingston':2007, 'Didier Ilunga-Mbenga':2007, 'Adam Morrison':2007, 'Corey Brewer':2000, 'Mickael Gelabale':2001, 'Jason Smith':2000, 'Al Jefferson':2009, 'Leon Powe':2009, 'Kareem Rush':2009, 'Michael Redd':[2009,2010], 'Jeff Ayres':2010, 'Kendrick Perkins':2010, 'Josh Howard':[2010,2012], 'Othyus Jeffers':2011, 'Gani Lawal':2011, 'David West':2011, 'Eric Maynor':2012, 'Derrick Rose':2012, 'Ricky Rubio':2012, 'Brandon Rush':2012, 'Iman Shumpert':2012, 'Leandro Barbosa':2013, 'Rajon Rondo':2013, 'Lou Williams':2013, 'Danilo Gallinari':2013, 'Nate Robinson':2014, 'J.J. Hickson':2014, 'Tony Wroten':2015, 'Jarrett Jack':2016, 'Dante Exum':2016}

# %%
def
