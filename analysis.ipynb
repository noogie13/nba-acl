# %% [markdown]
# # just some stuff here

# %%
from players import *
from raw_players import players_raw
import numpy

# %%
player_list = [Player(name,years) for name,years in players_raw.items()]

# %%
player_list[3].stats
# Out:
#       Unnamed: 0    Year         Player Pos   Age   Tm     G    GS      MP  \
# 4829        4829  1977.0  Mitch Kupchak   C  22.0  WSB  82.0   NaN  1513.0
# 5203        5203  1978.0  Mitch Kupchak  PF  23.0  WSB  67.0   NaN  1759.0
# 5562        5562  1979.0  Mitch Kupchak  PF  24.0  WSB  66.0   NaN  1604.0
# 5917        5917  1980.0  Mitch Kupchak  PF  25.0  WSB  40.0   NaN   451.0
# 6276        6276  1981.0  Mitch Kupchak  PF  26.0  WSB  82.0   NaN  1934.0
# 6643        6643  1982.0  Mitch Kupchak  PF  27.0  LAL  26.0  26.0   821.0
# 7379        7379  1984.0  Mitch Kupchak  PF  29.0  LAL  34.0   3.0   324.0
# 7729        7729  1985.0  Mitch Kupchak  PF  30.0  LAL  58.0   3.0   716.0
# 8104        8104  1986.0  Mitch Kupchak  PF  31.0  LAL  55.0   0.0   783.0
#
#        PER  ...    FT%    ORB    DRB    TRB   AST   STL   BLK    TOV     PF  \
# 4829  19.3  ...  0.691  183.0  311.0  494.0  62.0  22.0  34.0    NaN  204.0
# 5203  17.7  ...  0.697  162.0  298.0  460.0  71.0  28.0  42.0  184.0  196.0
# 5562  19.4  ...  0.743  152.0  278.0  430.0  88.0  23.0  23.0  120.0  141.0
# 5917   9.7  ...  0.693   32.0   73.0  105.0  16.0   8.0   8.0   40.0   49.0
# 6276  16.6  ...  0.706  198.0  371.0  569.0  62.0  36.0  26.0  161.0  195.0
# 6643  15.2  ...  0.663   64.0  146.0  210.0  33.0  12.0  10.0   43.0   80.0
# 7379   7.0  ...  0.647   35.0   52.0   87.0   7.0   4.0   6.0   22.0   46.0
# 7729  12.5  ...  0.659   68.0  116.0  184.0  21.0  19.0  20.0   48.0  104.0
# 8104  10.7  ...  0.750   69.0  122.0  191.0  17.0  12.0   7.0   64.0  102.0
#
#          PTS
# 4829   852.0
# 5203  1066.0
# 5562   961.0
# 5917   186.0
# 6276  1024.0
# 6643   371.0
# 7379   104.0
# 7729   306.0
# 8104   332.0
#
# [9 rows x 53 columns]

# %%
plot_stat(player_list,ppg,1)

# %%
plot_stat(player_list,ppg,2)

# %%
plot_stat(player_list,g,2)

# %%
plot_stat(player_list,g,1)

# %%
plot_stat(player_list,m,1)

# %%
plot_stat(player_list,mpg,2)

# %%
plot_stat(player_list,mpg,3)
