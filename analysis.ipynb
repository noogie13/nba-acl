# %%
from players import *
from raw_players import players_raw
import numpy

# %% [markdown]
# # NBA ACL injuries: is treatment improving?

# %% [markdown]
# # Outline:
# * Problem significance
# * Description

# %% [markdown]
# # Methods:

# %% [markdown]
# Got a database of player data per season from Kaggle.

# %%
total_stats = pd.read_csv('data/Seasons_Stats.csv')
total_stats.head(5)
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# Gathered the list of players from this photo:

# %%
from IPython.display import Image
Image(filename='tweet.png')

# %%
player_list = [Player(name,years) for name,years in players_raw.items()]
player_list[0].stats
# Out:
#       Unnamed: 0    Year             Player Pos   Age   Tm     G  GS      MP  \
# 2243        2243  1966.0  Billy Cunningham*  SF  22.0  PHI  80.0 NaN  2134.0
# 2378        2378  1967.0  Billy Cunningham*  SF  23.0  PHI  81.0 NaN  2168.0
# 2518        2518  1968.0  Billy Cunningham*  SF  24.0  PHI  74.0 NaN  2076.0
# 2697        2697  1969.0  Billy Cunningham*  PF  25.0  PHI  82.0 NaN  3345.0
# 2902        2902  1970.0  Billy Cunningham*  SF  26.0  PHI  81.0 NaN  3194.0
# 3117        3117  1971.0  Billy Cunningham*  SF  27.0  PHI  81.0 NaN  3090.0
# 3359        3359  1972.0  Billy Cunningham*  SF  28.0  PHI  75.0 NaN  2900.0
# 4163        4163  1975.0  Billy Cunningham*  SF  31.0  PHI  80.0 NaN  2859.0
# 4431        4431  1976.0  Billy Cunningham*  SF  32.0  PHI  20.0 NaN   640.0
#
#        PER  ...    FT%    ORB    DRB     TRB    AST   STL   BLK  TOV     PF  \
# 2243  15.7  ...  0.634    NaN    NaN   599.0  207.0   NaN   NaN  NaN  301.0
# ...

# %% [markdown]
# ## Points per game

# %%
plot_stat(player_list,ppg,1)

# %%
plot_stat(player_list,ppg,2)

# %%
plot_stat(player_list,ppg,3)

# %% [markdown]
# ## Minutes per game

# %%
plot_stat(player_list,mpg,1)

# %%
plot_stat(player_list,mpg,2)

# %%
plot_stat(player_list,mpg,3)

# %% [markdown]
# ## Games per season

# %%
plot_stat(player_list,g,1)

# %%
plot_stat(player_list,g,2)

# %%
plot_stat(player_list,g,3)

# %% [markdown]
# ## Assists per game

# %%
plot_stat(player_list,apg,1)

# %%
plot_stat(player_list,apg,2)

# %%
plot_stat(player_list,apg,3)

# %% [markdown]
# # Conclusions & Future Work

# %% [markdown]
# # References
# * https://github.com/noogie13/nba-acl
# * https://www.kaggle.com/drgilermo/nba-players-stats (Date Accessed: Nov 21, 2019)
# * https://www.sfchronicle.com/warriors/article/Klay-Thompson-injury-How-NBA-players-have-13999213.php (Date Accessed: Dec 2, 2019)
