# %%
from players import *
from raw_players import players_raw
import numpy

# %% [markdown]
# # NBA ACL injuries: is treatment improving?

# %% [markdown]
# # Methods:

# %% [markdown]
# Got a database of player data per season from Kaggle.

# %%
total_stats = pd.read_csv('data/Seasons_Stats.csv')
total_stats.head(5)
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# Gathered the list of players from this photo:

# %%
from IPython.display import Image
Image(filename='tweet.png')

# %%
player_list = [Player(name,years) for name,years in players_raw.items()]
player_list[1].stats
# Out:
#       Unnamed: 0    Year        Player Pos   Age   Tm     G  GS      MP   PER  \
# 3892        3892  1974.0  Doug Collins  SG  22.0  PHI  25.0 NaN   436.0  10.5
# 4160        4160  1975.0  Doug Collins  SG  23.0  PHI  81.0 NaN  2820.0  16.4
# 4427        4427  1976.0  Doug Collins  SG  24.0  PHI  77.0 NaN  2995.0  16.7
# 4714        4714  1977.0  Doug Collins  SG  25.0  PHI  58.0 NaN  2037.0  16.7
# 5080        5080  1978.0  Doug Collins  SG  26.0  PHI  79.0 NaN  2770.0  16.9
# 5448        5448  1979.0  Doug Collins  SG  27.0  PHI  47.0 NaN  1595.0  16.0
# 5795        5795  1980.0  Doug Collins  SG  28.0  PHI  36.0 NaN   963.0  13.6
# 6141        6141  1981.0  Doug Collins  SG  29.0  PHI  12.0 NaN   329.0  13.1
#
#       ...    FT%    ORB    DRB    TRB    AST    STL   BLK    TOV     PF  \
# 3892  ...  0.764    7.0   39.0   46.0   40.0   13.0   2.0    NaN   65.0
# 4160  ...  0.844  104.0  211.0  315.0  213.0  108.0  17.0    NaN  291.0
# ...

# %%
plot_stat(player_list,ppg,3)

# %%
plot_stat(player_list,g,5)

# %%
plot_stat(player_list,m,5)

# %%
plot_stat(player_list,mpg,5)

# %%
plot_stat(player_list,mpg,4)
